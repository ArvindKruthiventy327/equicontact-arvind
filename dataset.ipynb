# %%
import os
import pickle as pkl 
dataset_dir = "/extra_storage/data_collection/datasets/stack"
with open(os.path.join(dataset_dir, "demo_1.pkl"), "rb") as f: 
    data = pkl.load(f)
    print(f"Keys: {data.keys()}")
    print(data["observations"][0].keys())
    print(data["observations"][0]["robot0_eef_pos"])
# Out:
# Keys: dict_keys(['observations', 'actions', 'stage'])
# odict_keys(['robot0_joint_pos', 'robot0_joint_pos_cos', 'robot0_joint_pos_sin', 'robot0_joint_vel', 'robot0_eef_pos', 'robot0_eef_quat', 'robot0_eef_quat_site', 'robot0_gripper_qpos', 'robot0_gripper_qvel', 'robot0_eye_in_hand_back_image', 'agentview_image', 'robot0_eye_in_hand_image', 'robot0_proprio-state', 'robot0_eef_vel_body', 'cubeA_pos', 'cubeA_quat', 'cubeB_pos', 'cubeB_quat'])
# [0.61029713 0.00798689 0.00061431]

# %%
import os
import pickle as pkl
